# %%
df = pd.read_pickle('Complete_NST_Text.pkl')

#cleans \n slashes from text
df['text'] = df['text'].replace(r'\n', ' ', regex=True)

#creates a list of states
state_list = list(df['State'].groupby(df['State']).count().index)

#applies a number to each state
state_dict = {}
for idx, state in enumerate(state_list):
    state_dict[state] = idx

#drops any rows where State = NA
df = df.dropna(subset=['State'])

#applies the code to each row
df['state_code'] = df['State'].apply(lambda x: state_dict[x])

# %%
import pandas as pd

from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %%
text = df['text'].iloc[3]

# %%
text
# Out:
# 'Image caption Three people were killed when an explosion ripped through St Patrick\'s church on Tuesday  Fourteen people have been arrested in Nigeria after this week\'s attacks on a church and police stations in the northern city of Maiduguri, police say.  At least 14 people were killed in three explosions, including three people outside St Patrick\'s Catholic Church.  In a separate incident on Tuesday, a Christian preacher was shot dead by gunmen on motorcycles, police say.  The attacks have been blamed on the Boko Haram Islamist sect, which is fighting to overthrow Nigeria\'s state.  Police say they recovered four AK-47 assault rifles and a motorcycle when they made the arrests.  Boko Haram gunmen on bikes have killed dozens of police officers and politicians in the past year.  Preacher David Usman and one of his secretaries at the Church of Christ in Nigeria were the latest victims of such shootings, police say.  On Monday Ibrahim Birkuti, a cleric from a different Muslim tradition who had criticised Boko Haram, was shot dead outside his home in the town of Biu, some 200km (120 miles) south of Maiduguri.  \'Prisoners well treated\'  Some Boko Haram members have claimed that those arrested are being killed by members of the prison service and say this is why they have been targeting prison warders.  But the head of the prison service in Borno State, of which Maiduguri is the capital, told the BBC this was not true.  "We did not kill anybody," Malam Usman Abdulkareem Maina Kaina said.  He said some of those arrested had been freed on bail, while others had been transferred elsewhere in Nigeria.  He promised that any warder who mistreated an inmate would be disciplined.  Boko Haram believes that Western education is wrong.  In 2009, hundreds of its supporters, including its leader Mohammed Yusuf, were killed in Maiduguri after they attacked police stations.  Last week, Boko Haram told the BBC it had carried out a series of bombings after President Goodluck Jonathan\'s inauguration.  A sect spokesman said it was also responsible for killing the brother of the Shehu of Borno, one of Nigeria\'s most important Islamic leaders.  The police have made hundreds of arrests and even banned motorcycles at night but have not been able to stop the violence.'

# %%
text_list = list(text.split(' '))

# %%
killed_keys = []
for key,word in enumerate(text_list):
    if word == 'bodies':
        killed_keys.append(key)

# %%
killed_keys
# Out:
# []

# %%
text_list[177-3:177+3]
# Out:
# ['Haram,', 'was', 'shot', 'dead', 'outside', 'his']

# %%
words_to_check = ['killed', 'dead', 'died']

# %%
word_list = []
for word_1 in words_to_check: #iterates through the words to check
    for key, word_2 in enumerate(text_list): #iterates through the text
        if word_2 == word_1: #checks if each word in text matches key word
            word_list.append(text_list[key-3:key+3]) #appends word and surrounding words

flat_list = [item for sublist in word_list for item in sublist]

# %%
import re

# %%
def grab_words(text):

    #stop_words = set(stopwords.words('english'))
    text = re.sub(r'\W', " ", text)
 
    text = word_tokenize(text)
    #filtered_sentence = [w.lower() for w in text if not w in stop_words]
    words_to_check = ['killed', 'dead', 'died']
    word_list = []
    for word_1 in words_to_check: #iterates through the words to check
        for key, word_2 in enumerate(text): #iterates through the text
            if word_2 == word_1: #checks if each word in text matches key word
                word_list.append(text[key-5:key+5]) #appends word and surrounding words

    flat_list = [item for sublist in word_list for item in sublist] 
    final_string = ' '.join(flat_list)
    if len(final_string)>0:
        return final_string
    else:
        return "none"

# %%
df['kill_words'] = df['text'].apply(lambda x: grab_words(x))

# %%
df.columns
# Out:
# Index(['Title', 'Date', 'Community (city,town, ward)', 'LGA', 'State',
#        'Total Deaths', 'Boko Haram (P)', 'State Actor (P)',
#        'Sectarian Actor (excluding BH) (P)', 'Other Armed Actor (P)',
#        'Kidnapper (P)', 'Robber (P)', 'Other (P)',
#        'Election-related Actor (P)', 'Cameroon State Actor (P)',
#        'Boko Haram (V)', 'State Actor (V)', 'Sectarian Actor (V)',
#        'Other Armed Actor (V)', 'Political Actor (V)', 'Kidnapper (V)',
#        'Kidnapee (V)', 'Robber (V)', 'Journalist (V)', 'Civilian (V)',
#        'Election-related Actor (V)', 'Cameroon State Actor', 'Bomb', 'Gun',
#        'Machete', 'Suicide Bombing', 'Other Weapon', 'TK',
#        'Drinking Establishment', 'Goverment Building', 'Church', 'Mosque',
#        'Bank', 'School', 'Other Location', 'Notes', 'Sources 1', 'Sources 2',
#        'Sources 3', 'Latitude', 'Longitude', 'full place name', 'country',
#        'text', 'state_code', 'kill_words'],
#       dtype='object')

# %%
def cat_killed(x):
    if x is str:
        if x.isdigit() == True:
            if int(x) == 0:
                return 0
            elif int(x) > 0 and int(x) < 6:
                return 1
            elif int(x) > 5 and int(x) < 11:
                return 2
            elif int(x) > 10 and int(x) < 16:
                return 3
            elif int(x) > 15 and int(x) < 21:
                return 4
            elif int(x) > 20:
                return 5
    else:
        return 'not a digit'

# %%
df['cat_killed'] = df['Total Deaths'].apply(lambda x: cat_killed(x))

# %%
df['TD_Types'] = df['Total Deaths'].apply(lambda x: type(x))

# %%
df.head(50)
# Out:
#                                                 Title        Date  \
# 0   Army Barracks Attack Ahead of Goodluck Jonatha...   5/29/2011
# 1                                              Kaduna   5/29/2011
# 2                             Morning Attack in Zaria   5/30/2011
# 5        Militants Kill Muslim Cleric Ibrahim Burkuti    6/6/2011
# 6   Bomb Blasts Outside St. Patrick's Catholic Church    6/7/2011
# 7                          Bombing of Kano Motor Park    6/7/2011
# 8                          David Usman and  Shot Dead    6/7/2011
# 12                      Attack on Nigeria's Police HQ   6/16/2011
# 13                            Bank Assault in Katsina   6/20/2011
# 14            Gunmen Kill Police Officer in Maiduguri   6/20/2011
# 15         Militants Attack Police Station in Katsina   6/20/2011
# 18  Suspected Pirates Ambush Police Officers in Ba...   6/21/2011
# 19            Bomb Explosion at Maiduguri Beer Parlor   6/26/2011
# 20              Bomb Attack at Maiduguri Custom House   6/27/2011
# 22  Mustafa BArmed Actorsle Assassinated in Maiduguri    7/3/2011
# 25    Boko Haram Attacks Military Patrol in Maiduguri    7/6/2011
# 29    Police Brutality After Bomb Blasts in Maiduguri    7/9/2011
# 30                  Attack on JTF Forces in Maiduguri   7/10/2011
# 31                  Bomb Explosion at Hotel in Kaduna   7/10/2011
# 32    Bomb Kills At Least Three Churchgoers in Suleja   7/10/2011
# 82                      Borno                1     Boko Haram             NaN
# 86                      Borno                3     Boko Haram             NaN
# 87                      Borno                2     Boko Haram             NaN
# 89                      Borno                3            NaN             NaN
# 90                    Plateau                2            NaN             NaN
# 91                      Borno                2            NaN     State Actor
# 95                      Borno                1     Boko Haram             NaN
#
#    Sectarian Actor (excluding BH) (P) Other Armed Actor (P)     ...       \
# 0                                 NaN                   NaN     ...
# 1                                 NaN                   NaN     ...
# 2                                 NaN                   NaN     ...
# 5                                 NaN                   NaN     ...
# 6                                 NaN                   NaN     ...
# 7                                 NaN                   NaN     ...
# 8                                 NaN                   NaN     ...
# 12                                NaN                   NaN     ...
# 13                                NaN                   NaN     ...
# 14                                NaN                   NaN     ...
# 15                                NaN                   NaN     ...
# 18                    Sectarian Actor                   NaN     ...
# 19                                NaN                   NaN     ...
# 20                                NaN                   NaN     ...
# 22                                NaN                   NaN     ...
# 25                                NaN                   NaN     ...
# 29                                NaN                   NaN     ...
# 30                                NaN                   NaN     ...
# 31                                NaN                   NaN     ...
# 32                                NaN                   NaN     ...
# 35                                NaN                   NaN     ...
# 36                    Sectarian Actor                   NaN     ...
# 41                    Sectarian Actor                   NaN     ...
# 43                                NaN                   NaN     ...
# 44                                NaN                   NaN     ...
# 45                                NaN                   NaN     ...
# 46                                NaN                   NaN     ...
# 47                                NaN                   NaN     ...
# 52                    Sectarian Actor                   NaN     ...
# 56                    Sectarian Actor                   NaN     ...
# 59                    Sectarian Actor                   NaN     ...
# 60                    Sectarian Actor                   NaN     ...
# 61                                NaN                   NaN     ...
# 62                                NaN                   NaN     ...
# 64                    Sectarian Actor                   NaN     ...
# 67                                NaN                   NaN     ...
# 68                                NaN                   NaN     ...
# 69                    Sectarian Actor                   NaN     ...
# 70                    Sectarian Actor                   NaN     ...
# 76                    Sectarian Actor                   NaN     ...
# 77                    Sectarian Actor                   NaN     ...
# 78                    Sectarian Actor                   NaN     ...
# 81                                NaN                   NaN     ...
# 82                                NaN                   NaN     ...
# 86                                NaN                   NaN     ...
# 87                                NaN                   NaN     ...
# 89                                NaN                   NaN     ...
# 90                                NaN                   NaN     ...
# 91                                NaN                   NaN     ...
# 95                                NaN                   NaN     ...
#
#                                             Sources 3 Latitude Longitude  \
# 0   http://www.vanguardngr.com/2011/06/boko-haram-...  #ERROR!   #ERROR!
# 1      http://allafrica.com/stories/201105310901.html  #ERROR!   #ERROR!
# 2   http://weeklytrust.com.ng/?option=com_content&...  #ERROR!   #ERROR!
# 5                                            BBC, AFP      NaN       NaN
# 6   http://news.xinhuanet.com/english2010/world/20...      NaN       NaN
# 7                                                 NaN      NaN       NaN
# 8                                                 NaN      NaN       NaN
# 12                                                NaN  #ERROR!   #ERROR!
# 13                                                NaN      NaN       NaN
# 14                                                NaN      NaN       NaN
# 15                                                NaN      NaN       NaN
# 18     http://allafrica.com/stories/201106220597.html  #ERROR!   #ERROR!
# 19  http://online.wsj.com/article/SB10001424052702...      NaN       NaN
# 20                                                NaN      NaN       NaN
# 22                                                NaN      NaN       NaN
# 25                                                NaN      NaN       NaN
# 82  a former Nigerian president Gunmen killed the ...  <class 'str'>
# 86  adding that three civilians were killed Reside...  <class 'str'>
# 87  adding that three civilians were killed Reside...  <class 'str'>
# 89                                               none  <class 'str'>
# 90                                               none  <class 'str'>
# 91  Reuters Nigerian security forces shot dead two...  <class 'str'>
# 95  headquarters in the country that killed 23 peo...  <class 'str'>
#
#      cat_killed
# 0   not a digit
# 1   not a digit
# 2   not a digit
# 5   not a digit
# 6   not a digit
# 7   not a digit
# 8   not a digit
# 12  not a digit
# 13  not a digit
# 14  not a digit
# 15  not a digit
# 18  not a digit
# 19  not a digit
# 20  not a digit
# 22  not a digit
# 25  not a digit
# 29  not a digit
# 30  not a digit
# 31  not a digit
# 32  not a digit
# 35  not a digit
# 36  not a digit
# 41  not a digit
# 43  not a digit
# 44  not a digit
# 45  not a digit
# 46  not a digit
# 47  not a digit
# 52  not a digit
# 56  not a digit
# 59  not a digit
# 60  not a digit
# 61  not a digit
# 62  not a digit
# 64  not a digit
# 67  not a digit
# 68  not a digit
# 69  not a digit
# 70  not a digit
# 76  not a digit
# 77  not a digit
# 78  not a digit
# 81  not a digit
# 82  not a digit
# 86  not a digit
# 87  not a digit
# 89  not a digit
# 90  not a digit
# 91  not a digit
# 95  not a digit
#
# [50 rows x 53 columns]

# %%
pd.set_option('display.max_rows', 10000)

# %%
df['Total Deaths'] = pd.to_numeric(df['Total Deaths'],errors='coerce')

# %%
df['Total Deaths'] = df['Total Deaths'].dropna()

# %%
df[]

# %%
stop_words = set(stopwords.words('english'))
text = re.sub(r'\W', " ", text_test)
#text = list(str(text).split(' '))
text = word_tokenize(text)
filtered_sentence = [w.lower() for w in text if not w in stop_words]
filtered_sentence
# Out:
# ['kano',
#  'january',
#  '28',
#  'thewill',
#  'the',
#  'kano',
#  'state',
#  'police',
#  'command',
#  'saturday',
#  'confirmed',
#  'slaying',
#  'one',
#  'fresh',
#  'confrontation',
#  'members',
#  'terrorist',
#  'islamic',
#  'sect',
#  'boko',
#  'haram',
#  'the',
#  'command',
#  'also',
#  'said',
#  '4',
#  'boko',
#  'haram',
#  'terrorists',
#  'killed',
#  'yesterday',
#  'gun',
#  'fight',
#  'lasted',
#  'several',
#  'hours',
#  'attacked',
#  'mandawari',
#  'police',
#  'station',
#  'a',
#  'police',
#  'constable',
#  'identified',
#  'muktari',
#  'bello',
#  'killed',
#  'sect',
#  'attempted',
#  'attack',
#  'police',
#  'station',
#  'city',
#  'the',
#  'commissioner',
#  'police',
#  'ibrahim',
#  'idris',
#  'said',
#  'gunmen',
#  'met',
#  'stiff',
#  'resistance',
#  'confronted',
#  'superior',
#  'fire',
#  'power',
#  'exhibited',
#  'men',
#  'when',
#  'got',
#  'wind',
#  'attack',
#  'mandawari',
#  'ancient',
#  'city',
#  'immediately',
#  'mobilized',
#  'attack',
#  'lost',
#  'officer',
#  'constable',
#  'he',
#  'said',
#  'police',
#  'strengthened',
#  'security',
#  'around',
#  'state',
#  'guarantee',
#  'security',
#  'law',
#  'abiding',
#  'residents',
#  'state',
#  'anxiety',
#  'high',
#  'since',
#  'boko',
#  'haram',
#  'gained',
#  'entry',
#  'kano',
#  'unleashed',
#  'terror',
#  'state',
#  'leaving',
#  'many',
#  '200',
#  'people',
#  'dead',
#  'the',
#  'renewed',
#  'attacks',
#  'city',
#  'left',
#  'businesses',
#  'closed',
#  'vehicles',
#  'streets']

# %%
df['kill_words'].loc[44]
# Out:
# []

# %%
df['kill_words']
# Out:
# 0       [[allowed, to, sell, food,, drink, and], [Chri...
# 1                                                      []
# 2                                                      []
# 5       [[caption, Three, people, were, killed, when],...
# 6       [[graduated, to, the, use, of, deadly], [the, ...
# 7       [[], [northern, Borno, state,, leaving, at, le...
# 8       [[caption, Three, people, were, killed, when],...
# 12      [[of, people, had, gathered, to, watch], [spok...
# 13                [[the, police, station, at, the, same]]
# 14                                                     []
# 15                [[the, police, station, at, the, same]]
# 18             [[waterways, of, Bayelsa, State, as, two]]
# 19      [[Shariah, law,, but, several, outdoor, beer],...
# 20      [[the, customs, office, as, officials, inside]...
# 22      [[terror, attacks, on, the, Western, nations],...
# 25        [[is, in, lockdown,, with, residents, staying]]
# 29      [[wise, to, leave, the, area, because], [More,...
# 30      [[Obalende, district, of, Kaduna., A, senior],...
# 31      [[Obalende, district, of, Kaduna., A, senior],...
# 32            [[--, Three, people, were, killed, Sunday]]
# 35      [[out, of, the, area., , The], [fire, on, them...
# 36      [[clashes, , Five, people, were, killed], [on,...
# 41          [[rash, of, targeted, attacks, in, northern]]
# 43                                                     []
# 44                                                     []
# 45      [[Road,, Maiduguri., , ``The, explosion, was],...
# 46            [[Task, Force, in, Maiduguri, today, shot]]
# 47                                                     []
# 52      [[University,, DELSU,, Abraka, in, Delta, Stat...
# 56                                                     []
#                               ...
# 3541      [[Six, persons, have, been, allegedly, killed]]
# 3543                         [[", As, it, is, now,, the]]
# 3545                  [[in, Kogi, on, Friday, shot, and]]
# 3547                                                   []
# 3556                                                   []
# 3563    [[Wednesday, said, one, person, was, killed], ...
# 3587     [[than, eight, persons, have, been, reportedly]]
# 3592    [[than, 10, persons, were, on, Thursday], [and...
# 3593    [[than, 10, persons, were, on, Thursday], [and...
# 3608         [[as, Egberipapa,, is, a, former, militant]]
# 3614    [[after, an, Army, Major, and, a], [of, Rivers...
# 3644         [[started, on, Wednes­day,, when, one, out]]
# 3740    [[have, advised, students, to, avoid, belonging]]
# 3742           [[one, month., , Confirming, the, latest]]
# 3806    [[the, council, is, working, hard, to], [men, ...
# 3811          [[students, of, the, Federal, College, of]]
# 3861                                                   []
# 3882                                                   []
# 3954    [[new, generation, bank, yesterday, shot, dead...
# 3970                                                   []
# 3983    [[Suspected, gunmen, have, allegedly, killed, ...
# 4003                                                   []
# 4092    [[Calabar, South, Local, Government, Area, kil...
# 4113                                                   []
# 4136    [[his, assailant, who, laid, am­bush, as], [gr...
# 4146                                                   []
# 4152                                                   []
# 4168    [[Gunmen, operating, on, motor, cycle, shot], ...
# 4460                                                   []
# 5635    [[Delta, State,, was, shot, on, Tuesday], [the...
# Name: kill_words, Length: 4271, dtype: object
