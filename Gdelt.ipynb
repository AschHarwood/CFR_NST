# %%
import gdelt

# %%
import pandas as pd

# %%
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 500)

# %%
gd2 = gdelt.gdelt(version=2)

# %%
results = gd2.Search('2018 Feb 19')

# %%
results.head()
# Out:
#    GLOBALEVENTID   SQLDATE  MonthYear  Year  FractionDate Actor1Code  \
# 0      732229441  20170219     201702  2017     2017.1342        AUS
# 1      732229442  20170219     201702  2017     2017.1342        IND
# 2      732229443  20170219     201702  2017     2017.1342        IND
# 3      732229444  20170219     201702  2017     2017.1342        ITA
# 4      732229445  20170219     201702  2017     2017.1342        MED
#
#   Actor1Name Actor1CountryCode Actor1KnownGroupCode Actor1EthnicCode  \
# 0  AUSTRALIA               AUS                  NaN              NaN
# 1     BOMBAY               IND                  NaN              NaN
# 2     BOMBAY               IND                  NaN              NaN
# 3      ITALY               ITA                  NaN              NaN
# 4  NEWSPAPER               NaN                  NaN              NaN
#
#   Actor1Religion1Code Actor1Religion2Code Actor1Type1Code Actor1Type2Code  \
# ...

# %%
results[results['Actor1CountryCode']=='NIG']
# Out:
# Empty DataFrame
# ...

# %%
df = pd.DataFrame(results)

# %%
df.head()
# Out:
# pandas.core.frame.DataFrame
